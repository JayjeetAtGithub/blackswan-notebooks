# %%
pip install influxdb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from influxdb import InfluxDBClient, DataFrameClient
df_client = DataFrameClient('scruffy.soe.ucsc.edu', 8086, 'root', 'root', 'test_dev')
df_client.ping()
import pandas as pd
import json
from datetime import datetime

# %%
df_client.ping()
# Out:
# '1.7.9'

# %%
df_client.query('select * from machine_information')['machine_information']
# Out:
#                                     architecture blockdevice_sda_model  \
# 2020-01-01 16:30:25.016507904+00:00        amd64       BHYVE SATA DISK
# 2020-01-01 16:49:18.537433088+00:00        amd64       BHYVE SATA DISK
# 2020-01-01 16:49:21.595854080+00:00        amd64       BHYVE SATA DISK
#
#                                      blockdevice_sda_size  \
# 2020-01-01 16:30:25.016507904+00:00           63999836160
# 2020-01-01 16:49:18.537433088+00:00           63999836160
# 2020-01-01 16:49:21.595854080+00:00           63999836160
#
#                                     blockdevice_sda_vendor  \
# 2020-01-01 16:30:25.016507904+00:00                    ATA
# 2020-01-01 16:49:18.537433088+00:00                    ATA
# 2020-01-01 16:49:21.595854080+00:00                    ATA
#
#                                     blockdevice_sr0_model  \
# 2020-01-01 16:30:25.016507904+00:00         BHYVE DVD-ROM
# 2020-01-01 16:49:18.537433088+00:00         BHYVE DVD-ROM
# ...
